# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeerthP-10/Machine/blob/main/Ml_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df=df.iloc[:,1:]
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 83   7.5  130.0
# 9    5.1   66.0
# 48   6.6  138.0
# 62   6.0  102.0
# 65   8.1  166.0
# ..   ...    ...
# 82   6.5   37.0
# 39   4.6  146.0
# 64   7.0   64.0
# 46   5.3  114.0
# 55   7.8  114.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 83    1
# 9     0
# 48    1
# 62    0
# 65    1
#      ..
# 82    1
# 39    0
# 64    1
# 46    0
# 55    1
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.34709085,  0.20865817],
#        [-0.82110306, -1.38957464],
#        [ 0.53401813,  0.40843727],
#        [-0.00803035, -0.49056868],
#        [ 1.88913932,  1.10766413],
#        [-1.81485861, -0.54051346],
#        [-0.73076165, -0.29078958],
#        [ 0.80504237,  0.40843727],
#        [ 1.16640802, -0.14095525],
#        [-0.73076165,  0.98280219],
#        [ 0.98572519,  0.73307831],
#        [-0.27905459,  1.18258129],
#        [ 2.25050498, -0.0410657 ],
#        [ 0.08231107, -0.46559629],
#        [-0.73076165,  2.55606261],
#        [ 1.43743226,  0.1587134 ],
#        [ 0.44367672,  0.9578298 ],
#        [ 0.44367672, -0.79023733],
#        [ 0.71470096,  0.48335444],
#        [ 0.53401813, -0.0410657 ],
#        [ 1.16640802,  0.38346489],
#        [-1.00178589,  0.30854772],
#        [-0.82110306,  1.357388  ],
#        [-1.0921273 , -0.24084481],
#        [ 0.89538378,  0.43340966],
#        [-0.27905459,  0.53329921],
#        [ 0.08231107, -1.01498882],
# ...

# %%
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[ 0.26299389,  0.1587134 ],
#        [ 0.89538378, -0.24084481],
#        [-0.55007883,  0.43340966],
#        [-1.18246872, -0.8651545 ],
#        [-1.18246872, -0.01609332],
#        [-2.4472485 ,  1.53219472],
#        [-0.73076165,  0.25860295],
#        [ 2.06982215,  1.1576089 ],
#        [ 0.3533353 ,  0.48335444],
#        [ 0.89538378,  1.93175292]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
sample = np.array([1, 30]).reshape(1, -1)
model.predict(sample)
# Out:
# array([1])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x_train,y_train.values,model,legend=2)
# Out:
# <Axes: >

# %%
import pickle
pickle.dump(model,open('model.pkl','wb'))
pickle.dump(scaler, open('scaler.pkl', 'wb'))

# %%
from google.colab import files
files.download('model.pkl')
files.download('scaler.pkl')
